# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Mounted at /content/gdrive/

# %%
# !git clone https://github.com/ultralytics/yolov5

# %%
# %cd /content/gdrive/MyDrive/yolov5/
# Out:
# /content/gdrive/MyDrive/yolov5

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.6/190.6 kB 3.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 645.2/645.2 kB 20.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 7.5 MB/s eta 0:00:00
# ...

# %%
# !python train.py --data /content/gdrive/MyDrive/yolov5/img/data.yaml --cfg /content/gdrive/MyDrive/yolov5/models/yolov5s.yaml --weights yolov5s.pt --batch 16 --epochs 50 --name yewon
# Out:
# 2023-11-07 02:14:12.066927: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-07 02:14:12.066991: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-07 02:14:12.067034: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python val.py --data "/content/gdrive/MyDrive/yolov5/img/data.yaml" --img 1280 --weights "/content/gdrive/MyDrive/yolov5/runs/train/yewon2/weights/best.pt"

# %%
# !python detect.py --img 1280 --weights "/content/gdrive/MyDrive/yolov5/runs/train/yewon2/weights/best.pt" --source "/content/gdrive/MyDrive/arrow_img/test4.jpg" --save-txt

# %%
# zip 파일로 압축
# !zip -r /content/gdrive/MyDrive/yolov5.zip /content/gdrive/MyDrive/yolov5
# Out:
# updating: content/gdrive/MyDrive/yolov5/ (stored 0%)
# updating: content/gdrive/MyDrive/yolov5/.dockerignore (deflated 56%)
# updating: content/gdrive/MyDrive/yolov5/README.md (deflated 79%)
# updating: content/gdrive/MyDrive/yolov5/hubconf.py (deflated 73%)
# updating: content/gdrive/MyDrive/yolov5/utils/ (stored 0%)
# updating: content/gdrive/MyDrive/yolov5/utils/segment/ (stored 0%)
# updating: content/gdrive/MyDrive/yolov5/utils/segment/augmentations.py (deflated 62%)
# updating: content/gdrive/MyDrive/yolov5/utils/segment/general.py (deflated 71%)
# updating: content/gdrive/MyDrive/yolov5/utils/segment/__init__.py (stored 0%)
# updating: content/gdrive/MyDrive/yolov5/utils/segment/plots.py (deflated 64%)
# updating: content/gdrive/MyDrive/yolov5/utils/segment/loss.py (deflated 66%)
# updating: content/gdrive/MyDrive/yolov5/utils/segment/metrics.py (deflated 76%)
# updating: content/gdrive/MyDrive/yolov5/utils/segment/dataloaders.py (deflated 72%)
# ...
